# %% [markdown]
# <a href="https://colab.research.google.com/github/karodeakshat064/machine-learning-csit/blob/main/Copy_of_Autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 128  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='RMSprop', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=68,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.2755 - val_loss: 0.2048
# Epoch 2/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1852 - val_loss: 0.1683
# Epoch 3/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1590 - val_loss: 0.1489
# Epoch 4/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1430 - val_loss: 0.1353
# Epoch 5/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1315 - val_loss: 0.1251
# Epoch 6/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1225 - val_loss: 0.1171
# Epoch 7/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1151 - val_loss: 0.1104
# Epoch 8/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.1090 - val_loss: 0.1049
# Epoch 9/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1040 - val_loss: 0.1005
# Epoch 10/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0999 - val_loss: 0.0968
# Epoch 11/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0966 - val_loss: 0.0939
# Epoch 12/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0940 - val_loss: 0.0915
# Epoch 13/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0918 - val_loss: 0.0897
# Epoch 14/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0899 - val_loss: 0.0880
# Epoch 15/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0884 - val_loss: 0.0865
# Epoch 16/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0871 - val_loss: 0.0854
# Epoch 17/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0859 - val_loss: 0.0843
# Epoch 18/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0849 - val_loss: 0.0834
# Epoch 19/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0840 - val_loss: 0.0825
# Epoch 20/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0832 - val_loss: 0.0818
# Epoch 21/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0824 - val_loss: 0.0811
# Epoch 22/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0818 - val_loss: 0.0805
# Epoch 23/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0811 - val_loss: 0.0799
# Epoch 24/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0806 - val_loss: 0.0794
# Epoch 25/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0800 - val_loss: 0.0789
# Epoch 26/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0795 - val_loss: 0.0785
# Epoch 27/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0791 - val_loss: 0.0780
# Epoch 28/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0786 - val_loss: 0.0776
# Epoch 29/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0782 - val_loss: 0.0772
# Epoch 30/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0778 - val_loss: 0.0769
# Epoch 31/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0775 - val_loss: 0.0765
# Epoch 32/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0771 - val_loss: 0.0762
# Epoch 33/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0768 - val_loss: 0.0759
# Epoch 34/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0765 - val_loss: 0.0756
# Epoch 35/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0762 - val_loss: 0.0753
# Epoch 36/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0759 - val_loss: 0.0751
# Epoch 37/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0757 - val_loss: 0.0748
# Epoch 38/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0754 - val_loss: 0.0746
# Epoch 39/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0752 - val_loss: 0.0744
# Epoch 40/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0750 - val_loss: 0.0742
# Epoch 41/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0748 - val_loss: 0.0740
# Epoch 42/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0745 - val_loss: 0.0738
# Epoch 43/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0744 - val_loss: 0.0736
# Epoch 44/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0742 - val_loss: 0.0735
# Epoch 45/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0740 - val_loss: 0.0733
# Epoch 46/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0738 - val_loss: 0.0731
# Epoch 47/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0736 - val_loss: 0.0729
# Epoch 48/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0735 - val_loss: 0.0728
# Epoch 49/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0733 - val_loss: 0.0726
# Epoch 50/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0732 - val_loss: 0.0725
# Epoch 51/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0730 - val_loss: 0.0724
# Epoch 52/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0729 - val_loss: 0.0723
# Epoch 53/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0728 - val_loss: 0.0721
# Epoch 54/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0727 - val_loss: 0.0720
# Epoch 55/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0725 - val_loss: 0.0719
# Epoch 56/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0724 - val_loss: 0.0718
# Epoch 57/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0723 - val_loss: 0.0717
# Epoch 58/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0722 - val_loss: 0.0716
# Epoch 59/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0721 - val_loss: 0.0715
# Epoch 60/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0720 - val_loss: 0.0714
# Epoch 61/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0719 - val_loss: 0.0713
# Epoch 62/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0718 - val_loss: 0.0712
# Epoch 63/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0717 - val_loss: 0.0711
# Epoch 64/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 65/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 66/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0714 - val_loss: 0.0709
# Epoch 67/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0713 - val_loss: 0.0708
# Epoch 68/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0712 - val_loss: 0.0707

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of the encoded representation
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoding layers
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoding layers
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Encoder model
encoder = Model(input_img, encoded)

# Decoder model
encoded_input = Input(shape=(encoding_dim,))
decoder_layer1 = autoencoder.layers[-3]
decoder_layer2 = autoencoder.layers[-2]
decoder_layer3 = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer3(decoder_layer2(decoder_layer1(encoded_input))))

# %%
# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.2456 - val_loss: 0.1720
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1554 - val_loss: 0.1396
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1333 - val_loss: 0.1256
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1231 - val_loss: 0.1178
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1165 - val_loss: 0.1128
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1126 - val_loss: 0.1095
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.1096 - val_loss: 0.1066
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1065 - val_loss: 0.1042
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.1039 - val_loss: 0.1014
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1019 - val_loss: 0.1000
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1003 - val_loss: 0.0987
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0991 - val_loss: 0.0980
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0982 - val_loss: 0.0968
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0972 - val_loss: 0.0961
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0964 - val_loss: 0.0950
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0954 - val_loss: 0.0942
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0945 - val_loss: 0.0933
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0938 - val_loss: 0.0927
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0916 - val_loss: 0.0909
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0911 - val_loss: 0.0900
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0906 - val_loss: 0.0896
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0901 - val_loss: 0.0891
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0898 - val_loss: 0.0888
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0894 - val_loss: 0.0884
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0891 - val_loss: 0.0883
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0888 - val_loss: 0.0879
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0885 - val_loss: 0.0876
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0882 - val_loss: 0.0874
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0880 - val_loss: 0.0872
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0877 - val_loss: 0.0870
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0875 - val_loss: 0.0871
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0873 - val_loss: 0.0866
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0871 - val_loss: 0.0866
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0870 - val_loss: 0.0864
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0868 - val_loss: 0.0862
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0866 - val_loss: 0.0862
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0864 - val_loss: 0.0858
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0862 - val_loss: 0.0859
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0861 - val_loss: 0.0857
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0859 - val_loss: 0.0852
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0857 - val_loss: 0.0853
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0856 - val_loss: 0.0852
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0855 - val_loss: 0.0853
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0853 - val_loss: 0.0851
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0852 - val_loss: 0.0848
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0851 - val_loss: 0.0851
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0850 - val_loss: 0.0846

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
